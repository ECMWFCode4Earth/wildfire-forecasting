# %% [markdown]
# # Predicting FWI using deepFWI Pre-trained models

# %% [markdown]
# ### Introduction
# The Fire Weather Index (FWI) is a meteorologically based index used worldwide to estimate fire danger. It consists of different components that account for the effects of fuel moisture and wind on fire behaviour and spread. The higher the FWI, the more favorable the meteorological conditions to trigger a wildfire. This indicator can help shape long-term tourist strategy and to plan future investments under a changing climate.
#
# The [`esowc/wildfire-forecasting`](https://github.com/esowc/wildfire-forecasting) project intends to reproduce the Fire Forecasting capabilities of GEFF using Deep Learning and develop further improvements in accuracy, geography and time scale through inclusion of additional variables or optimisation of model architecture & hyperparameters.
#
# In this notebook we demonstrate the use of pre-trained Deep Learning models to perform FWI inference. The Deep Learning Model has been trained on 1 year of data and takes as input the four weather forcings used in the numerical calculation of FWI:
# ```
# * t2    -    Temperature at 2m
# * tp    -    Total Precipitation
# * rh    -    Relative Humidity
# * wspeed-    Windspeed
# ```
#
# These input weather forcings are supplied for 4 days and the model produces FWI forecast for 10 days. There is 1 day of overlap between the 4 weather forcing variable inputs and the output FWI forecast as indicated below:
# ```
#                                        ____________
# Weather Forcings (t-3, t-2, t-1, t) -> | deepFWI  |  -> deepFWI-Forecast (t, t+1, t+2, ..., t+9)
#                                        ------------
# ```
#
# Along with FWI inference using deepGEFF pre-trained models, we also benchmark these results against the baseline `FWI-Forecast` which are numerically calculated FWI predictions from weather forecast.
#
# To run this notebook, make sure you have the `wildfire-dl` `conda` environment activated. Instructions for setting up the environment are available in the project [`README`](https://github.com/esowc/wildfire-forecasting/blob/master/README.md).

# %% [markdown]
# ### Getting the data
#
# We first obtain a sample dataset (~`1.5GB` in size). This is the minimum data that we need to perform inference and then benchmark the results. This data is stored on a publicly accessible GCP bucket at `gs://deepfwi-mini-sample` and is downloaded into `data/mini_sample/`

# %%
import os
os.chdir('..')

# %% [markdown]
# ### Ensure access to the data
# The `/data/add_swvl1/` dataset contains the following data -
# * `fwi-forcings/`: Weather Forcings for 2019-12-01 to 2019-12-04 --> 4 days --> 4 files
# * `fwi-forecast/`: Numerical FWI Predictions for 2019-12-04 to 2019-12-13 --> 10 days --> 1 file
# * `fwi-reanalysis/`: ERA Reanalysis of FWI for 2019-12-04 to 2019-12-13 --> 10 days --> 10 files
#
#
# If you wish to explore these datasets further, have a look at the EDA notebooks in `data/EDA/` in the repository.

# %% [markdown]
# ### Running the inference and the benchmark
#
# For performing inference and then benchmarking the results, we use the `run(**kwargs)` function from [`src/test.py`](https://github.com/esowc/wildfire-forecasting/blob/master/src/test.py) which takes as argument a dict of configuration parameters and boolean for `benchmark`. You can check out more details about this function in [`test.py#L266`](https://github.com/esowc/wildfire-forecasting/blob/master/src/test.py#L266)

# %%
from src.test import run

# %% [markdown]
# Providing the configuration options,
#
# ```
# * in_days        -    no of input days of weather forcings
# * out_days       -    no of output days of fwi prediction
# * checkpoint_file-    path to pretrained checkpoint file
# * reanalysis_dir -    path to fwi-reanalysis data
# * forcings_dir   -    path to fwi-forcings data
# * forecast_dir   -    path to fwi-forecast data
# ```

# %%
config = dict(
    in_days=4,
    out_days=10,
    checkpoint_file="/home/esowc/wildfire-forecasting/src/model/checkpoints/unet_tapered-fwi_reanalysis-4-10--10/17-03:39unet_tapered-fwi_reanalysis-4-10--10/17-03:39_ckpt_epoch_29.ckpt",
    forcings_dir="/home/esowc/data/add_swvl1/fwi-forcings",
    reanalysis_dir="/home/esowc/data/add_swvl1/fwi-reanalysis",
    forecast_dir="/home/esowc/data/add_swvl1/fwi-forecast"
)

# %% [markdown]
# ### Results
#
# We demonstrate below the metrics (accuracy, mean-squared-error and mean-absolute-error) for deepFWI predicted values and benchmark them against the mumeical fwi-forecast prediction values. These metrics are for 1 FWI prediction (for 10 days) in a global setting. The metrics are calculated against fwi-reanalysis (considered the ground truth). The grouped bar plots indicate the metrics for deepFWI while the line plots are used for fwi-forecast. The FWI values are binned as per the EFFIS categorisation:
#
# ```
# * [0, 5.2]     - Very Low
# * (5.2, 11.2]  - Low
# * (11.2, 21.3] - Moderate
# * (21.3, 38.0] - High
# * (38.0, 50.0] - Very High
# * (50.0, Inf)  - Extreme
# ```
#
# As seen, the deepFWI predictions are consistent with FWI-Forecast and even offer better accuracy for longer term predictions in certain FWI categories.

# %%
run(**config, benchmark=True);
# Out:
# Doing inference with the model..
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/wildfire-forecasting/src/test.py in main(hparams, verbose)
#      69     try:
# ---> 70         result = trainer.test(model, verbose=verbose)[0]
#      71     except:
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/states.py in wrapped_fn(self, *args, **kwargs)
#      47                 self.state = entering
# ---> 48             result = fn(self, *args, **kwargs)
#      49
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in test(self, model, test_dataloaders, ckpt_path, verbose, datamodule)
#    1354         if model is not None:
# -> 1355             results = self.__test_given_model(model, test_dataloaders)
#    1356         else:
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in __test_given_model(self, model, test_dataloaders)
#    1417         self.model = model
# -> 1418         results = self.fit(model)
#    1419         self.testing = False
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/states.py in wrapped_fn(self, *args, **kwargs)
#      47                 self.state = entering
# ---> 48             result = fn(self, *args, **kwargs)
#      49
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#    1072             model = self.accelerator_backend.setup(model)
# -> 1073             results = self.accelerator_backend.train(model)
#    1074
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/accelerators/gpu_backend.py in train(self, model)
#      50     def train(self, model):
# ---> 51         results = self.trainer.run_pretrain_routine(model)
#      52         return results
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in run_pretrain_routine(self, model)
#    1208             # self.reset_test_dataloader(ref_model)
# -> 1209             eval_loop_results, _ = self.run_evaluation(test_mode=True)
#    1210
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in run_evaluation(self, test_mode)
#     581         # run evaluation (val_step + val_step_end + val_epoch_end)
# --> 582         eval_results = self._evaluate(self.model, dataloaders, max_batches, test_mode)
#     583
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in _evaluate(self, model, dataloaders, max_batches, test_mode)
#     332                 else:
# --> 333                     output = self.evaluation_forward(model, batch, batch_idx, dataloader_idx, test_mode)
#     334
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in evaluation_forward(self, model, batch, batch_idx, dataloader_idx, test_mode)
#     684         if test_mode:
# --> 685             output = model.test_step(*args)
#     686         else:
#
# ~/wildfire-forecasting/src/model/base_model.py in test_step(self, batch, batch_idx)
#     101             if self.hparams.benchmark
# --> 102             else self.data.test_step(self, batch)
#     103         )
#
# ~/wildfire-forecasting/src/dataloader/base_loader.py in test_step(self, model, batch)
#     488         x, y_pre = batch
# --> 489         y_hat_pre = model(x)
#     490
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#
# ~/wildfire-forecasting/src/model/unet_tapered.py in forward(self, x)
#      49         """
# ---> 50         enc1 = self.encoder1(x)
#      51         enc2 = self.encoder2(self.pool1(enc1))
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     418     def forward(self, input: Tensor) -> Tensor:
# --> 419         return self._conv_forward(input, self.weight)
#     420
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     411         if self.padding_mode != 'zeros':
# --> 412             return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     413                             weight, self.bias, self.stride,
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/functional.py in _pad(input, pad, mode, value)
#    3572             elif mode == 'circular':
# -> 3573                 return _pad_circular(input, pad)
#    3574             else:
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/torch/nn/functional.py in _pad_circular(input, padding)
#    3840     input = torch.cat([input, input[:, :, 0:padding[-1]]], dim=2)
# -> 3841     input = torch.cat([input[:, :, -(padding[-1] + padding[-2]):-padding[-1]], input], dim=2)
#    3842
#
# RuntimeError: CUDA out of memory. Tried to allocate 1002.00 MiB (GPU 0; 10.76 GiB total capacity; 3.01 GiB already allocated; 596.44 MiB free; 3.02 GiB reserved in total by PyTorch)
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-a3eb702991b8> in <module>
# ----> 1 run(**config, benchmark=True);
#
# ~/wildfire-forecasting/src/test.py in run(**kwargs)
#     285         print("Doing inference with the model..")
#     286         hparams.benchmark = False
# --> 287         result, _ = main(hparams=hparams, verbose=False)
#     288         hparams.benchmark = True
#     289
#
# ~/wildfire-forecasting/src/test.py in main(hparams, verbose)
#      70         result = trainer.test(model, verbose=verbose)[0]
#      71     except:
# ---> 72         result = trainer.test(model)[0]
#      73
#      74     return result, model.hparams
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/states.py in wrapped_fn(self, *args, **kwargs)
#      46             if entering is not None:
#      47                 self.state = entering
# ---> 48             result = fn(self, *args, **kwargs)
#      49
#      50             # The INTERRUPTED state can be set inside the run function. To indicate that run was interrupted
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in test(self, model, test_dataloaders, ckpt_path, verbose, datamodule)
#    1353
#    1354         if model is not None:
# -> 1355             results = self.__test_given_model(model, test_dataloaders)
#    1356         else:
#    1357             results = self.__test_using_best_weights(ckpt_path, test_dataloaders)
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in __test_given_model(self, model, test_dataloaders)
#    1416         self.testing = True
#    1417         self.model = model
# -> 1418         results = self.fit(model)
#    1419         self.testing = False
#    1420
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/states.py in wrapped_fn(self, *args, **kwargs)
#      46             if entering is not None:
#      47                 self.state = entering
# ---> 48             result = fn(self, *args, **kwargs)
#      49
#      50             # The INTERRUPTED state can be set inside the run function. To indicate that run was interrupted
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#    1071             self.accelerator_backend = GPUBackend(self)
#    1072             model = self.accelerator_backend.setup(model)
# -> 1073             results = self.accelerator_backend.train(model)
#    1074
#    1075         elif self.use_tpu:
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/accelerators/gpu_backend.py in train(self, model)
#      49
#      50     def train(self, model):
# ---> 51         results = self.trainer.run_pretrain_routine(model)
#      52         return results
#      53
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py in run_pretrain_routine(self, model)
#    1207             # only load test dataloader for testing
#    1208             # self.reset_test_dataloader(ref_model)
# -> 1209             eval_loop_results, _ = self.run_evaluation(test_mode=True)
#    1210
#    1211             if len(eval_loop_results) == 0:
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in run_evaluation(self, test_mode)
#     580
#     581         # run evaluation (val_step + val_step_end + val_epoch_end)
# --> 582         eval_results = self._evaluate(self.model, dataloaders, max_batches, test_mode)
#     583
#     584         # log the final eval loop metrics
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in _evaluate(self, model, dataloaders, max_batches, test_mode)
#     331                         output = self.evaluation_forward(model, batch, batch_idx, dataloader_idx, test_mode)
#     332                 else:
# --> 333                     output = self.evaluation_forward(model, batch, batch_idx, dataloader_idx, test_mode)
#     334
#     335                 is_result_obj = isinstance(output, Result)
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/evaluation_loop.py in evaluation_forward(self, model, batch, batch_idx, dataloader_idx, test_mode)
#     673             if isinstance(self.data_parallel_device_ids, list):
#     674                 root_gpu = self.data_parallel_device_ids[0]
# --> 675             batch = self.transfer_batch_to_gpu(batch, root_gpu)
#     676             args[0] = batch
#     677
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/distrib_parts.py in transfer_batch_to_gpu(self, batch, gpu_id)
#     172         """
#     173         device = torch.device('cuda', gpu_id)
# --> 174         return self.__transfer_batch_to_device(batch, device)
#     175
#     176     def __transfer_batch_to_device(self, batch: Any, device: torch.device):
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/trainer/distrib_parts.py in __transfer_batch_to_device(self, batch, device)
#     177         model = self.get_model()
#     178         if model is not None:
# --> 179             return model.transfer_batch_to_device(batch, device)
#     180         return move_data_to_device(batch, device)
#     181
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/core/hooks.py in transfer_batch_to_device(self, batch, device)
#     380             - :func:`~pytorch_lightning.utilities.apply_func.apply_to_collection`
#     381         """
# --> 382         return move_data_to_device(batch, device)
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/utilities/apply_func.py in move_data_to_device(batch, device)
#     122         return data.to(device, **kwargs)
#     123
# --> 124     return apply_to_collection(batch, dtype=(TransferableDataType, Batch), function=batch_to)
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/utilities/apply_func.py in apply_to_collection(data, dtype, function, *args, **kwargs)
#      56         return elem_type(*(apply_to_collection(d, dtype, function, *args, **kwargs) for d in data))
#      57     elif isinstance(data, Sequence) and not isinstance(data, str):
# ---> 58         return elem_type([apply_to_collection(d, dtype, function, *args, **kwargs) for d in data])
#      59
#      60     # data is neither of dtype, nor a collection
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/utilities/apply_func.py in <listcomp>(.0)
#      56         return elem_type(*(apply_to_collection(d, dtype, function, *args, **kwargs) for d in data))
#      57     elif isinstance(data, Sequence) and not isinstance(data, str):
# ---> 58         return elem_type([apply_to_collection(d, dtype, function, *args, **kwargs) for d in data])
#      59
#      60     # data is neither of dtype, nor a collection
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/utilities/apply_func.py in apply_to_collection(data, dtype, function, *args, **kwargs)
#      47     # Breaking condition
#      48     if isinstance(data, dtype):
# ---> 49         return function(data, *args, **kwargs)
#      50
#      51     # Recursively apply to collection items
#
# ~/anaconda3/envs/wildfire-dl/lib/python3.7/site-packages/pytorch_lightning/utilities/apply_func.py in batch_to(data)
#     120
#     121         kwargs = dict(non_blocking=True) if isinstance(data, torch.Tensor) else {}
# --> 122         return data.to(device, **kwargs)
#     123
#     124     return apply_to_collection(batch, dtype=(TransferableDataType, Batch), function=batch_to)
#
# RuntimeError: CUDA out of memory. Tried to allocate 1000.00 MiB (GPU 0; 10.76 GiB total capacity; 3.01 GiB already allocated; 594.44 MiB free; 3.02 GiB reserved in total by PyTorch)
