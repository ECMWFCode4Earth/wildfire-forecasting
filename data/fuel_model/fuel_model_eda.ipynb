# %%
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %%
# !pip install xlrd -qq

# %%
import pandas as pd
dfs = pd.read_excel("glc2000/Global_Legend.xls", engine="xlrd")

# %%
dfs
# Out:
#     VALUE                                         CLASSNAMES       Red     Green      Blue
# 0       1                 Tree Cover, broadleaved, evergreen  0.000000  0.390000  0.000000
# 1       2         Tree Cover, broadleaved, deciduous, closed  0.000000  0.584314  0.000000
# 2       3           Tree Cover, broadleaved, deciduous, open  0.682353  0.996078  0.384314
# 3       4               Tree Cover, needle-leaved, evergreen  0.541176  0.266667  0.070588
# 4       5               Tree Cover, needle-leaved, deciduous  0.800000  0.494118  0.372549
# 5       6                        Tree Cover, mixed leaf type  0.545098  0.741176  0.000000
# 6       7         Tree Cover, regularly flooded, fresh water  0.466667  0.584314  0.996078
# 7       8        Tree Cover, regularly flooded, saline water  0.000000  0.274510  0.780392
# 8       9      Mosaic: Tree Cover / Other natural vegetation  0.000000  0.898039  0.000000
# 9      10                                  Tree Cover, burnt  0.000000  0.000000  0.000000
# 10     11                Shrub Cover, closed-open, evergreen  0.996078  0.462745  0.000000
# 11     12                Shrub Cover, closed-open, deciduous  0.996078  0.698039  0.000000
# 12     13                      Herbaceous Cover, closed-open  0.996078  0.913725  0.615686
# 13     14            Sparse herbaceous or sparse shrub cover  0.866667  0.788235  0.627451
# 14     15    Regularly flooded shrub and/or herbaceous cover  0.000000  0.584314  0.584314
# 15     16                       Cultivated and managed areas  0.996078  0.874510  0.894118
# 16     17  Mosaic: Cropland / Tree Cover / Other natural ...  0.996078  0.454902  0.905882
# 17     18        Mosaic: Cropland / Shrub and/or grass cover  0.788235  0.537255  0.996078
# 18     19                                         Bare Areas  0.701961  0.701961  0.701961
# 19     20                                       Water Bodies  0.537255  0.886275  0.996078
# 20     21                                       Snow and Ice  0.937255  0.937255  0.937255
# 21     22           Artificial surfaces and associated areas  0.996078  0.000000  0.000000
# 22     23                                            No data  0.996078  0.996078  0.996078

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = xr.open_rasterio('glc2000/glc2000_v1_1.tif', chunks={'band': 1, 'x': 1024, 'y': 1024})

# %%
data
# Out:
# <xarray.DataArray (band: 1, y: 16353, x: 40320)>
# dask.array<open_rasterio-a9dac518a79696312d85dec405e162ce<this-array>, shape=(1, 16353, 40320), dtype=uint8, chunksize=(1, 1024, 1024), chunktype=numpy.ndarray>
# Coordinates:
#   * band     (band) int64 1
#   * y        (y) float64 89.99 89.98 89.97 89.96 ... -55.98 -55.99 -56.0 -56.01
#   * x        (x) float64 -180.0 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0 180.0
# Attributes:
#     transform:               (0.0089285714, 0.0, -180.0044642857, 0.0, -0.008...
#     crs:
#     res:                     (0.0089285714, 0.0089285714)
#     is_tiled:                0
#     nodatavals:              (nan,)
#     scales:                  (1.0,)
#     offsets:                 (0.0,)
#     AREA_OR_POINT:           Point
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_SOFTWARE:        Arc/Info
#     TIFFTAG_XRESOLUTION:     112
#     TIFFTAG_YRESOLUTION:     112

# %%
data.values
# Out:
# array([[[20, 20, 20, ..., 20, 20, 20],
#         [20, 20, 20, ..., 20, 20, 20],
#         [20, 20, 20, ..., 20, 20, 20],
#         ...,
#         [20, 20, 20, ..., 20, 20, 20],
#         [20, 20, 20, ..., 20, 20, 20],
#         [20, 20, 20, ..., 20, 20, 20]]], dtype=uint8)

# %%
data.values.shape
# Out:
# (1, 16353, 40320)

# %% [markdown]
# ### Range (long, lat): `-21.75, 72.25` *top-left* to  `45.25, 26.75` *bottom-right*

# %%
sub_data = data.sel(band=1, x=slice(-21.75, 45.25), y=slice(72.25, 26.75))

# %%
sub_data = sub_data.rename({'y': 'lat', 'x': 'lon'})

# %%
sub_data
# Out:
# <xarray.DataArray (lat: 5096, lon: 7504)>
# dask.array<getitem, shape=(5096, 7504), dtype=uint8, chunksize=(1024, 1024), chunktype=numpy.ndarray>
# Coordinates:
#     band     int64 1
#   * lat      (lat) float64 72.24 72.23 72.22 72.21 ... 26.78 26.77 26.76 26.75
#   * lon      (lon) float64 -21.74 -21.73 -21.72 -21.71 ... 45.23 45.24 45.25
# Attributes:
#     transform:               (0.0089285714, 0.0, -180.0044642857, 0.0, -0.008...
#     crs:
#     res:                     (0.0089285714, 0.0089285714)
#     is_tiled:                0
#     nodatavals:              (nan,)
#     scales:                  (1.0,)
#     offsets:                 (0.0,)
#     AREA_OR_POINT:           Point
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_SOFTWARE:        Arc/Info
#     TIFFTAG_XRESOLUTION:     112
#     TIFFTAG_YRESOLUTION:     112

# %%
sub_data.values
# Out:
# array([[20, 20, 20, ..., 20, 20, 20],
#        [20, 20, 20, ..., 20, 20, 20],
#        [20, 20, 20, ..., 20, 20, 20],
#        ...,
#        [20, 20, 20, ..., 19, 19, 19],
#        [20, 20, 20, ..., 19, 19, 19],
#        [20, 20, 20, ..., 19, 19, 19]], dtype=uint8)

# %%
sub_data.values.max()
# Out:
# 23

# %%
plt.imshow(sub_data.values/19*250, cmap='hsv')

# %%
sub_data
# Out:
# <xarray.DataArray (lat: 5096, lon: 7504)>
# dask.array<getitem, shape=(5096, 7504), dtype=uint8, chunksize=(1024, 1024), chunktype=numpy.ndarray>
# Coordinates:
#     band     int64 1
#   * lat      (lat) float64 72.24 72.23 72.22 72.21 ... 26.78 26.77 26.76 26.75
#   * lon      (lon) float64 -21.74 -21.73 -21.72 -21.71 ... 45.23 45.24 45.25
# Attributes:
#     transform:               (0.0089285714, 0.0, -180.0044642857, 0.0, -0.008...
#     crs:
#     res:                     (0.0089285714, 0.0089285714)
#     is_tiled:                0
#     nodatavals:              (nan,)
#     scales:                  (1.0,)
#     offsets:                 (0.0,)
#     AREA_OR_POINT:           Point
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_SOFTWARE:        Arc/Info
#     TIFFTAG_XRESOLUTION:     112
#     TIFFTAG_YRESOLUTION:     112

# %%
sub_data.to_netcdf(path='/root/fuel.nc4', format='NETCDF4')
